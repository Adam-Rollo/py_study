# %%
# %run poetry_gen.py --mode train
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7f8edf77b1d0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# 0/3350 (epoch 0) | train_loss 8.006
# model saved to log/model.ckpt
# 669/3350 (epoch 0) | train_loss 6.305
# 1000/3350 (epoch 1) | train_loss 5.525
# model saved to log/model.ckpt
# 1339/3350 (epoch 1) | train_loss 6.074
# 2000/3350 (epoch 2) | train_loss 5.784
# model saved to log/model.ckpt
# 2009/3350 (epoch 2) | train_loss 6.065
# 2679/3350 (epoch 3) | train_loss 5.953
# 3000/3350 (epoch 4) | train_loss 5.596
# model saved to log/model.ckpt
# 3349/3350 (epoch 4) | train_loss 5.859
# model saved to log/model.ckpt
#
# None

# %%
# %run poetry_gen.py --mode sample --head 滑头小妖牛逼
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7f8edf780940>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# INFO:tensorflow:Restoring parameters from log/model.ckpt-3350
# 生成藏头诗 --->  滑头小妖牛逼
# 滑客先遗始，头台帝自心。小阳清几日未分，妖邑忆风怀易传。牛前每自推醒卷，逼客有兵枫云声。

# %%
import argparse
import sys
import os
import io
import importlib
import time
import numpy as np
import collections
import tensorflow as tf
import tensorflow.contrib.rnn as rnn
import tensorflow.contrib.legacy_seq2seq as seq2seq

# %%
#help(collections.Counter)
c = collections.Counter('abcdeabcdabcaba')  
c.items()
# Out:
# dict_items([('b', 4), ('c', 3), ('a', 5), ('e', 1), ('d', 2)])

# %%
a = (1,2,3) + ('a',)
{i:j for i,j in enumerate(a) }

b = [4,5,6]
display(b[:-1])
b[:-1] = [7,8,9]
b
# Out:
# [4, 5]
# [7, 8, 9, 6]

# %%
# %run poetry_gen.py --mode train
# Out:
# ['^绵绢，割两耳，只有面。$',
#  '^桑条韦也，女时韦也乐。$',
#  '^欲得命通，问瑝嵎都雍。$',
#  '^斋钟动也，和尚不上堂。$',
#  '^子母相去离，连台拗倒。$',
#  '^势如连璧友，心似臭兰人。$',
#  '^不缘朝阙去，好此结茅庐。$',
#  '^鱼戏莲叶间，参差隐叶扇。$',
#  '^神羊既不触，夕鸟欲依人。$',
#  '^整巾千嶂耸，曳履百泉鸣。$',
#  '^清清江潭树，日夕增所思。$',
#  '^人家在仙掌，云气欲生衣。$',
#  '^初程莫早发，且宿灞桥头。$',
#  '^素练风霜起，苍鹰画作殊。$',
#  '^熊踞庭中树，龙蒸栋里云。$',
#  '^省署开文苑，沧浪学钓翁。$',
#  '^他乡生白发，旧国有青山。$',
#  '^情人共惆怅，良友不同游。$',
#  '^台笠冒山雨，渚田耕荇花。$',
#  '^诗书入京国，旌旆过乡关。$',
#  '^夫子生知者，相期妙理中。$',
#  '^谁云隼旟吏，长对虎头岩。$',
#  '^但虑彩色污，无虞臂胛肥。$',
#  '^夜入真珠室，朝游玳瑁宫。$',
#  '^地甃如拳石，溪横似叶舟。$',
#  '^积高依郡城，迥拔凌霄汉。$',
#  '^入门池色静，登阁雨声来。$',
#  '^绿迸穿篱笋，红飘隔户花。$',
#  '^吟倚雨残树，月收山下村。$',
#  '^河势昆仑远，山形菡萏秋。$',
#  '^万里岐路多，一身天地窄。$',
#  '^南浦花临水，东楼月映风。$',
#  '^水光先见月，露气早知秋。$',
#  '^雾纹斑似豹，水力健如龙。$',
#  '^塞鸿先秋去，边草入夏生。$',
#  '^项斯逢水部，谁道不关情。$',
#  '^成都十万户，抛若一鸿毛。$',
#  '^我本南山凤，岂同凡鸟群。$',
#  '^海曙云浮日，江遥水合天。$',
#  '^吾家九叶相，尽继明时出。$',
#  '^篆经千古涩，影泻一堂寒。$',
#  '^鱼戏莲叶间，参差隐叶扇。$',
#  '^君恩秋后叶，日日向人疏。$',
#  '^独来成怅望，不去泥栏干。$',
#  '^远来朝凤阙，归去恋元侯。$',
#  '^仕宦类商贾，终日常东西。$',
#  '^护犊横身立，逢人揭尾跳。$',
# ...

# %%
help(tf.nn.embedding_lookup)
# Out:
# Help on function embedding_lookup in module tensorflow.python.ops.embedding_ops:
#
# embedding_lookup(params, ids, partition_strategy='mod', name=None, validate_indices=True, max_norm=None)
#     Looks up `ids` in a list of embedding tensors.
#
#     This function is used to perform parallel lookups on the list of
#     tensors in `params`.  It is a generalization of
#     @{tf.gather}, where `params` is
#     interpreted as a partitioning of a large embedding tensor.  `params` may be
#     a `PartitionedVariable` as returned by using `tf.get_variable()` with a
#     partitioner.
#
#     If `len(params) > 1`, each element `id` of `ids` is partitioned between
#     the elements of `params` according to the `partition_strategy`.
#     In all strategies, if the id space does not evenly divide the number of
#     partitions, each of the first `(max_id + 1) % len(params)` partitions will
#     be assigned one more id.
#
# ...

# %%
help(tf.get_variable)
# Out:
# Help on function get_variable in module tensorflow.python.ops.variable_scope:
#
# get_variable(name, shape=None, dtype=None, initializer=None, regularizer=None, trainable=True, collections=None, caching_device=None, partitioner=None, validate_shape=True, use_resource=None, custom_getter=None, constraint=None)
#     Gets an existing variable with these parameters or create a new one.
#
#     This function prefixes the name with the current variable scope
#     and performs reuse checks. See the
#     @{$variables$Variable Scope How To}
#     for an extensive description of how reusing works. Here is a basic example:
#
#     ```python
#     def foo():
#       with tf.variable_scope("foo", reuse=tf.AUTO_REUSE):
#         v = tf.get_variable("v", [1])
#       return v
#
#     v1 = foo()  # Creates v.
#     v2 = foo()  # Gets the same, existing v.
#     assert v1 == v2
#     ```
#
#     If initializer is `None` (the default), the default initializer passed in
# ...
